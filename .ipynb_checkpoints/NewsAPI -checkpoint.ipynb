# %%
from newsapi import NewsApiClient
import json

# %%
newsapi = NewsApiClient(api_key='0f6bb26533f74234ab55c3d6bcee6de2')
top_headlines = newsapi.get_top_headlines(country='us')

# %%
print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 36, 'articles': [{'source': {'id': 'abc-news', 'name': 'ABC News'}, 'author': 'Bill Hutchinson', 'title': "Ahmaud Arbery death trial live updates: Prosecutor's rebuttal begins - ABC News", 'description': '', 'url': 'https://abcnews.go.com/US/live-updates/ahmaud-arbery/?id=81313519', 'urlToImage': 'https://s.abcnews.com/images/US/dunikowski-arbery-ap-ps-211123_1637677395563_hpMain_16x9_1600.jpg', 'publishedAt': '2021-11-23T14:18:00Z', 'content': 'The lead prosecutor got the final word on Tuesday before a Georgia jury is to begin deliberating the fates of three white men charged with trapping Ahmaud Arbery with their pickup trucks and fatally … [+1503 chars]'}, {'source': {'id': 'nfl-news', 'name': 'NFL News'}, 'author': None, 'title': 'NFL Power Rankings, Week 12: Patriots rise, Bills fall as pecking order changes from top to bottom - NFL.com', 'description': "In his Week 12 Power Rankings, Dan Hanzus makes changes at No. 1 and No. 32, with a whole lot
# ...

# %%
resultsNum = top_headlines['totalResults']
news = top_headlines["articles"]
for i in news:
    print("News Source: ",i["source"], "\n\t Author: ",i["author"], "\n\t Title: ",i["title"], "\n\t News: ",i["content"], "\n\t Published On: ", i["publishedAt"])
    print("\n\n")
# Out:
# News Source:  {'id': 'abc-news', 'name': 'ABC News'}
# 	 Author:  Bill Hutchinson
# 	 Title:  Ahmaud Arbery death trial live updates: Prosecutor's rebuttal begins - ABC News
# 	 News:  The lead prosecutor got the final word on Tuesday before a Georgia jury is to begin deliberating the fates of three white men charged with trapping Ahmaud Arbery with their pickup trucks and fatally … [+1503 chars]
# 	 Published On:  2021-11-23T14:18:00Z
#
#
#
# News Source:  {'id': 'nfl-news', 'name': 'NFL News'}
# 	 Author:  None
# 	 Title:  NFL Power Rankings, Week 12: Patriots rise, Bills fall as pecking order changes from top to bottom - NFL.com
# 	 News:  Who wants to rule the NFL?
# As we approach December, the league is experiencing an unusual dearth of superpowers. This absence of a true upper class has created a bloated middle class that makes each… [+404 chars]
# 	 Published On:  2021-11-23T13:34:00Z
#
#
#
# News Source:  {'id': None, 'name': 'New York Times'}
# 	 Author:  Alyssa Lukpat
# ...

# %%
print("Total number of News = ", resultsNum)
# Out:
# Total number of News =  36
